# %%
import pandas as pd
import glob
  
# path of the folder
path = r'src/datasets/o3plus'
  
# reading all the excel files
filenames = glob.glob(path + "\*.xlsx")
print('File names:', filenames)
  
# initializing empty data frame
finalexcelsheet = pd.DataFrame()
  
# to iterate excel file one by one 
# inside the folder
for file in filenames:
  
    # combining multiple excel worksheets
    # into single data frames
    df = pd.concat(pd.read_excel(
      file, sheet_name=None), ignore_index=True, sort=False)
  
    # appending excel files one by one
    finalexcelsheet = finalexcelsheet.append(
      df, ignore_index=True)
  
# to print the combined data
print('Final Sheet:')
display(finalexcelsheet)
  
finalexcelsheet.to_excel(r'src/datasets/o3plus/Final.xlsx', index=False)
# Out:
# File names: ['src/datasets/o3plus\\Tata cliq 06-01-2021.xlsx', 'src/datasets/o3plus\\Tata cliq order 04-01-2022.xlsx', 'src/datasets/o3plus\\Tata cliq order 05-01-2022.xlsx', 'src/datasets/o3plus\\Tata cliq order 07-01-2022.xlsx', 'src/datasets/o3plus\\Tata cliq order 08-01-2022.xlsx', 'src/datasets/o3plus\\Tata cliq order 10-01-2022.xlsx', 'src/datasets/o3plus\\Tata cliq order 11-01-2022.xlsx', 'src/datasets/o3plus\\Tata cliq order 13-01-2022.xlsx', 'src/datasets/o3plus\\Tata cliq order 14-01-2022.xlsx', 'src/datasets/o3plus\\Tata cliq order 15-01-2022.xlsx', 'src/datasets/o3plus\\Tata cliq order 17-01-2022.xlsx', 'src/datasets/o3plus\\Tata cliq order 18-01-2022.xlsx']
# Final Sheet:
#                                              Unnamed: 0   Unnamed: 1  \
# 0                                                   NaN          NaN
# 1                                            Row Labels  Sum of Qty
# 2     O3+ Bridal Facial Kit Oxygenating Glow Skin - ...            2
# 3     O3+ Bridal Facial Kit Vitamin C Glowing Skin -...            1
# 4     O3+ Brightening & Whitening Face Wash - 50 gmA...            1
# ...                                                 ...          ...
# 1262                                                NaN          NaN
# 1263                                                NaN          NaN
# 1264                                                NaN          NaN
# 1265                                                NaN          NaN
# 1266                                                NaN          NaN
#
#         Unnamed: 2                                SlrName  \
# 0              NaN                                    NaN
# 1     Sum of Price                                    NaN
# 2             1560                                    NaN
# 3              780                                    NaN
# 4              385                                    NaN
# ...            ...                                    ...
# 1262           NaN  Visage Beauty and Health Care Pvt Ltd
# 1263           NaN  Visage Beauty and Health Care Pvt Ltd
# 1264           NaN  Visage Beauty and Health Care Pvt Ltd
# 1265           NaN  Visage Beauty and Health Care Pvt Ltd
# 1266           NaN  Visage Beauty and Health Care Pvt Ltd
#
#                   OrderId      TransactionId           Ussid      SKU  \
# 0                     NaN                NaN             NaN      NaN
# 1                     NaN                NaN             NaN      NaN
# 2                     NaN                NaN             NaN      NaN
# 3                     NaN                NaN             NaN      NaN
# 4                     NaN                NaN             NaN      NaN
# ...                   ...                ...             ...      ...
# 1262  '220118-017-386206'  '126050023209542'  '126050O30026'  O3-0026
# 1263  '220117-017-376683'  '126050023191348'  '126050KIT243'  KIT-243
# 1264  '220117-017-376683'  '126050023191349'  '126050KIT243'  KIT-243
# 1265  '220118-017-384123'  '126050023205615'  '126050O30762'  O3-0762
# 1266  '220117-017-375816'  '126050023189602'  '126050O30877'  O3-0877
#
#                                             ProductName OrderType  ...  IMEI4  \
# 0                                                   NaN       NaN  ...    NaN
# 1                                                   NaN       NaN  ...    NaN
# 2                                                   NaN       NaN  ...    NaN
# 3                                                   NaN       NaN  ...    NaN
# 4                                                   NaN       NaN  ...    NaN
# ...                                                 ...       ...  ...    ...
# 1262  O3+ Brightening & Whitening Face Wash - 100 gm...       New  ...    NaN
# 1263  O3+ Anti-Ageing Facial Kit with Peel off Mask ...       New  ...    NaN
# 1264  O3+ Anti-Ageing Facial Kit with Peel off Mask ...       New  ...    NaN
# 1265  O3+ Plunge Avocado Brightening Glow Serum - 10...       New  ...    NaN
# 1266  O3+ Caffeine Bomb Anti Dark Circle Eye Patch -...       New  ...    NaN
#
#       Order Allocate Date Pack Date Slave Type  Refund Type  Local  Qty QTY   \
# 0                     NaN       NaN        NaN          NaN    NaN  NaN  NaN
# 1                     NaN       NaN        NaN          NaN    NaN  NaN  NaN
# 2                     NaN       NaN        NaN          NaN    NaN  NaN  NaN
# 3                     NaN       NaN        NaN          NaN    NaN  NaN  NaN
# 4                     NaN       NaN        NaN          NaN    NaN  NaN  NaN
# ...                   ...       ...        ...          ...    ...  ...  ...
# 1262  2022-01-18 08:04:47       NaN  Warehouse          NaN     No  NaN  1.0
# 1263  2022-01-17 21:25:51       NaN  Warehouse          NaN     No  NaN  1.0
# 1264  2022-01-17 21:25:51       NaN  Warehouse          NaN     No  NaN  1.0
# 1265  2022-01-18 01:18:38       NaN  Warehouse          NaN     No  NaN  1.0
# 1266  2022-01-17 21:01:27       NaN  Warehouse          NaN     No  NaN  1.0
#
#       qty   qty
# 0      NaN  NaN
# 1      NaN  NaN
# 2      NaN  NaN
# 3      NaN  NaN
# 4      NaN  NaN
# ...    ...  ...
# 1262   NaN  NaN
# 1263   NaN  NaN
# 1264   NaN  NaN
# 1265   NaN  NaN
# 1266   NaN  NaN
#
# [1267 rows x 91 columns]
